# %%
import networkx as nx

# %%
nx.__version__
# Out:
# '2.2'

# %%
g = nx.read_gpickle("../../mist-rrm-exp/test-notebooks/mistG_sams_4989.gpickle")

# %%
g.size()
# Out:
# 418

# %%
n =0 
# for e in g.edges():
#     rssi = g[e[0]][e[1]].get("RSSI")
    

len([x   for x in [ g[e[0]][e[1]].get("RSSI") for e in g.edges() ] if x > -65 ] )
# Out:
# 146

# %%
for ap in g:
    print(ap, g._node[ap].get("rf_overlap"),  g._node[ap].get("rf_overlap_cochn"))
# Out:
# 5c5b35ae1cb1:r5 6.8 None
# 5c5b35ae1b7b:r5 8.5 1.25
# 5c5b35ae1bf3:r5 5.6 0.51
# 5c5b35ae1da1:r5 13.5 None
# 5c5b35ae1d38:r5 5.7 None
# 5c5b35ae1b67:r5 7.8 None
# 5c5b35ae1699:r5 5.8 1.35
# 5c5b35ae1cd9:r5 7.9 1.46
# 5c5b35ae169e:r5 5.2 None
# 5c5b35ae16e4:r5 8.2 None
# d420b0000c35:r5 15.5 0.97
# d420b0000cf8:r5 14.0 None
# d420b0000ccb:r5 15.08 None
# 5c5b35ae1d10:r5 12.2 None
# 5c5b35ae1941:r5 8.7 None
# 5c5b35ae16bc:r5 8.3 None
# 5c5b35ae1680:r5 6.5 None
# d420b0000bae:r5 18.9 None
# d420b0000ce9:r5 15.74 None
# 5c5b35ae1d2e:r5 11.4 None
# 5c5b35ae1b80:r5 6.2 None
# 5c5b35ae1ce3:r5 5.8 None
# 5c5b35ae1ed2:r5 9.2 None
# 5c5b35ae1d33:r5 13.5 2.45
# 5c5b35ae1bfd:r5 6.0 None
# 5c5b35ae18a1:r5 6.2 1.8
# 5c5b35ae1d06:r5 7.7 4.17
# 5c5b35ae1d24:r5 6.7 None
# 5c5b35ae1b58:r5 7.2 None
# 5c5b35ae1d3d:r5 8.8 1.46
# 5c5b35ae1d92:r5 9.5 None
# 5c5b35ae1d1f:r5 8.4 None
# 5c5b35ae1752:r5 4.3 None
# 5c5b35ae1cf7:r5 7.9 None
# 5c5b35ae1757:r5 9.0 None
# d420b0000c67:r5 14.08 None
# ...

# %%
ap203 = "5c5b35ae16bc" + ":r5"

aps = ["5c5b35ae1d24", "5c5b35ae1680", "5c5b35ae1d2e"]  
aps = [x+ ":r5" for x in aps]

for ap2 in g.neighbors(ap203):
    print(ap2, g[ap2][ap203].get("RSSI"),  g[ap203][ap2].get("RSSI"))
# g._node[ap]
# mistG = g
# mistG.node[list(mistG.nodes())[0]]
# Out:
# 5c5b35ae1cf7:r5 -64.0 -66.0
# 5c5b35ae1752:r5 -55.0 -64.0
# 5c5b35ae1bfd:r5 -80 -64.0
# 5c5b35ae1b7b:r5 -66.0 -62.0
# 5c5b35ae1941:r5 -60.0 -59.0
# 5c5b35ae1cb1:r5 -65.0 -69.0
# 5c5b35ae1ce3:r5 -62.0 -54.0
# 5c5b35ae1d38:r5 -67.0 -66.0

# %%
# dir(g)
# !pwd
# Out:
# /opt/mistsys/ds_incubator/rrm

# %%
dirname = os.path.realpath("../../mist-rrm-exp/src") #os.path.dirname(os.path.realpath("../AP/"))

import sys
print(dirname)
if dirname not in sys.path:
    sys.path.insert(0, dirname)
    
# from common import plotgraph
# from common import mistGraph

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from importlib import reload
from common import graphPlotHelper
reload(graphPlotHelper)
plt.figure(figsize=(15, 20))
# graphPlotHelper.plotGraphColor(mistG, {}, False, "rrm_power")

graphPlotHelper.plotGraphColorByMap(g, {}, False, "rrm_power")
# Out:
# /opt/mistsys/mist-rrm-exp/src
# map_id=8c5497fd-f83f-4627-b0bb-2b6074c4569e
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
reload(graphPlotHelper)
# fig,ax=plt.subplots(figsize=plt.rcParams["figure.figsize"][::-1])

plt.figure(figsize=(15, 20))
# ax.invert_yaxis()
graphPlotHelper.plotGraphColor(g, {}, False, "rrm_power")

# # graphPlotHelper.plotGraphColorByMap(g, {}, False, "rrm_power")

# pos = graphPlotHelper.getPOS(g)
# pos
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...
