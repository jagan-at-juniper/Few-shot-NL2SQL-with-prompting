# %%
APP_NAMES_EXCLUDE_LIST = ['None', 'SSH', 'SSL', 'HTTP', 'DNS', 'HTTP2', 'junos-https', 'junos-http']

# %%
df = spark.read.parquet('s3://mist-secorapp-production/srx-flow-events-analytics/srx-flow-events-analytics-production/dt=2020-10-28/hr=*/*')
df.count()
# Out:
# 22492243

# %%
df_completed_session = df.filter('event_type == 2').persist()
df_completed_session.count()
# Out:
# 14175454

# %%
df_completed_session.printSchema()
# Out:
# root
#  |-- chassis_mac: string (nullable = true)
#  |-- org_id: string (nullable = true)
#  |-- site_id: string (nullable = true)
#  |-- srxipaddress: string (nullable = true)
#  |-- event_type: integer (nullable = true)
#  |-- event_occur_time: long (nullable = true)
#  |-- flow_session_id: integer (nullable = true)
#  |-- src_addr: string (nullable = true)
#  |-- dst_addr: string (nullable = true)
#  |-- src_port: integer (nullable = true)
#  |-- dst_port: integer (nullable = true)
#  |-- protocol_id: integer (nullable = true)
#  |-- session_close_reason: string (nullable = true)
#  |-- session_total_time: integer (nullable = true)
#  |-- secuirty_policy_name: string (nullable = true)
#  |-- src_zone_name: string (nullable = true)
#  |-- dst_zone_name: string (nullable = true)
#  |-- out_interface_name: string (nullable = true)
#  |-- routing_instance: string (nullable = true)
#  |-- pkts_from_client: long (nullable = true)
#  |-- bytes_from_client: long (nullable = true)
#  |-- pkts_from_server: long (nullable = true)
#  |-- bytes_from_server: long (nullable = true)
#  |-- service_name: string (nullable = true)
#  |-- application: string (nullable = true)
#  |-- nested_app: string (nullable = true)
#  |-- app_catagory: string (nullable = true)
#  |-- app_sub_catagory: string (nullable = true)
#  |-- encryted_status: boolean (nullable = true)
#  |-- nat_src_addr: string (nullable = true)
#  |-- nat_dst_addr: string (nullable = true)
#  |-- nat_src_port: integer (nullable = true)
#  |-- nat_dst_port: integer (nullable = true)
#  |-- src_nat_rule_name: string (nullable = true)
#  |-- dst_nat_rule_name: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- user_role: string (nullable = true)
#  |-- client_wcid: string (nullable = true)
#  |-- flow_start_time: long (nullable = true)
#  |-- flow_end_time: long (nullable = true)
#  |-- normalized_app: string (nullable = true)

# %%
# For each srx box, how many application sessions
srx_session_counts = df_completed_session.groupBy('chassis_mac').count().collect()
for r in srx_session_counts:
    print('srx_mac {}: session_count {}'.format(r['chassis_mac'], r['count']))
# Out:
# srx_mac 5800bba79000: session_count 25863
# srx_mac d8b122d38781: session_count 14325
# srx_mac d0dd49ebba7a: session_count 18588
# srx_mac fc334262af00: session_count 3850
# srx_mac 4c96144a3200: session_count 20086
# srx_mac 4c96144ff300: session_count 422
# srx_mac 30b64f25ce40: session_count 129836
# srx_mac 4c9614067d00: session_count 21168
# srx_mac fc33426df201: session_count 29218
# srx_mac f07cc745e489: session_count 133302
# srx_mac fc334263c380: session_count 871947
# srx_mac c8e7f0c878e9: session_count 63213
# srx_mac ec13dbdcd600: session_count 554
# srx_mac d8b122ae8b00: session_count 2019
# srx_mac 4c9614b2b000: session_count 21453
# srx_mac 4c9614abae00: session_count 21474
# srx_mac 0c81262d7e84: session_count 83984
# srx_mac fc3342640600: session_count 448083
# srx_mac 4c961411b900: session_count 284517
# srx_mac 94f7ad22c581: session_count 2909
# srx_mac 5800bbdca0bc: session_count 139
# srx_mac 5800bbdc5fbc: session_count 10648
# srx_mac 4c9614334100: session_count 20129
# srx_mac 0c81262dfa04: session_count 735
# srx_mac 2c2131521680: session_count 289166
# srx_mac f4bfa8527f46: session_count 80358
# srx_mac e8a24550c332: session_count 53021
# srx_mac 4071832aae80: session_count 29252
# srx_mac 0c812662a980: session_count 22216
# srx_mac d007caced048: session_count 90605
# srx_mac 784f9b262575: session_count 233277
# srx_mac f4cc55238d40: session_count 10363
# srx_mac 0c8126202648: session_count 172802
# srx_mac 9ccc83b1f480: session_count 235896
# srx_mac c8e7f0cf3dc4: session_count 16421
# srx_mac fc3342635080: session_count 2962
# srx_mac 4c9614380200: session_count 415
# srx_mac 4c9614978400: session_count 657149
# srx_mac fc3342640d80: session_count 107839
# srx_mac 4c9614927700: session_count 97264
# srx_mac 7c2586dbab49: session_count 662183
# srx_mac 0c8126626800: session_count 170346
# srx_mac 045c6c171959: session_count 1119664
# srx_mac c8e7f0cf22c4: session_count 49
# srx_mac 30b64f22bc80: session_count 99117
# srx_mac 4c9614ccb700: session_count 21314
# srx_mac ec13dbd51e01: session_count 19942
# srx_mac 4c96141d3c00: session_count 450757
# srx_mac 0c81266744e8: session_count 10569
# srx_mac 4c96147c8e00: session_count 18924
# srx_mac 84c1c1b04bc0: session_count 133
# srx_mac fc334263c580: session_count 61430
# srx_mac 0c81261848c8: session_count 345
# srx_mac 30b64f2ee0c0: session_count 1526
# srx_mac 4c9614386d00: session_count 21096
# srx_mac 4c96147e1400: session_count 553
# srx_mac fc3342636080: session_count 165215
# srx_mac e8a245413803: session_count 2201
# srx_mac d0dd49716381: session_count 91839
# srx_mac d007ca6962c0: session_count 144044
# srx_mac 4071832aac00: session_count 1
# srx_mac 4c9614844f00: session_count 20287
# srx_mac 20d80ba74102: session_count 540932
# srx_mac ec3873688cd0: session_count 12412
# srx_mac 30b64f2e6540: session_count 8209
# srx_mac b8c2537c2988: session_count 1777583
# srx_mac 807ff81ea74a: session_count 2792
# srx_mac 4c9614e00500: session_count 25840
# srx_mac 4c9614532200: session_count 21320
# srx_mac d8b122ae6a00: session_count 3339
# srx_mac 20d80ba0c700: session_count 170
# srx_mac 4c9614a89300: session_count 24905
# srx_mac 384f499fbe01: session_count 110817
# srx_mac 30b64f2e6b40: session_count 10368
# srx_mac 0c81262b2604: session_count 718
# srx_mac d0dd49709901: session_count 140781
# srx_mac 1039e94cd5c1: session_count 14024
# srx_mac 4c9614dd2800: session_count 21692
# srx_mac d0dd49e00400: session_count 23522
# srx_mac ec13dbd54a80: session_count 188
# srx_mac 30b64f21c980: session_count 192308
# srx_mac e8a245514eb2: session_count 145615
# srx_mac 94bf94bb8887: session_count 153838
# srx_mac fc3342641c00: session_count 122084
# srx_mac 94bf94b1986e: session_count 113515
# srx_mac d0dd49765481: session_count 98631
# srx_mac ec3873958c24: session_count 8040
# srx_mac e8a2455184b2: session_count 154431
# srx_mac 5800bbd8a881: session_count 11887
# srx_mac 4c9614df4700: session_count 24509
# srx_mac d0dd4971b400: session_count 148294
# srx_mac 4c9614eac100: session_count 655937
# srx_mac 0c812667c1e8: session_count 19734
# srx_mac 94bf94bbcb87: session_count 129916
# srx_mac f07cc7469b09: session_count 245855
# srx_mac d8b122d3aa81: session_count 11868
# srx_mac 0c812662a480: session_count 149559
# srx_mac e8a24551be32: session_count 57071
# srx_mac d8b122ac2e00: session_count 146603
# srx_mac ec3873638100: session_count 291
# srx_mac 045c6c91ab00: session_count 42235
# srx_mac 4c9614846200: session_count 96774
# srx_mac f4bfa853d646: session_count 151
# srx_mac 4c9614934500: session_count 20291
# srx_mac f4bfa8521346: session_count 58723
# srx_mac f4bfa8522846: session_count 161026
# srx_mac f07cc74a5a8c: session_count 24745
# srx_mac 94f7ada17180: session_count 5527
# srx_mac 94f7adf725a0: session_count 13791
# srx_mac e8a245513cb2: session_count 772357
# srx_mac fc334262bd80: session_count 23544
# srx_mac 5800bba87d00: session_count 16194
# srx_mac 4c9614dbe800: session_count 20370
# srx_mac 0c812667f568: session_count 11819
# srx_mac ec387368d450: session_count 163155
# srx_mac 30b64f219f00: session_count 6151

# %%
# For each srx box, how many unique src IPs

srx_src_ip_count = df_completed_session.select('chassis_mac', 'src_addr').dropDuplicates().groupBy('chassis_mac').count().collect()

for r in srx_src_ip_count:
    print('srx_mac {}: src_addr_count {}'.format(r['chassis_mac'], r['count']))
# Out:
# srx_mac 5800bba79000: src_addr_count 5
# srx_mac d8b122d38781: src_addr_count 7
# srx_mac d0dd49ebba7a: src_addr_count 23
# srx_mac fc334262af00: src_addr_count 4
# srx_mac 4c96144a3200: src_addr_count 1
# srx_mac 4c96144ff300: src_addr_count 1
# srx_mac 30b64f25ce40: src_addr_count 20
# srx_mac fc33426df201: src_addr_count 12
# srx_mac 4c9614067d00: src_addr_count 1
# srx_mac f07cc745e489: src_addr_count 75
# srx_mac fc334263c380: src_addr_count 80860
# srx_mac ec13dbdcd600: src_addr_count 41
# srx_mac c8e7f0c878e9: src_addr_count 16
# srx_mac d8b122ae8b00: src_addr_count 6
# srx_mac 4c9614b2b000: src_addr_count 1
# srx_mac 4c9614abae00: src_addr_count 1
# srx_mac fc3342640600: src_addr_count 36
# srx_mac 0c81262d7e84: src_addr_count 456
# srx_mac 4c961411b900: src_addr_count 1
# srx_mac 94f7ad22c581: src_addr_count 261
# srx_mac 5800bbdca0bc: src_addr_count 3
# srx_mac 5800bbdc5fbc: src_addr_count 4
# srx_mac 4c9614334100: src_addr_count 1
# srx_mac 0c81262dfa04: src_addr_count 2
# srx_mac 2c2131521680: src_addr_count 483
# srx_mac f4bfa8527f46: src_addr_count 21
# srx_mac 4071832aae80: src_addr_count 33
# srx_mac e8a24550c332: src_addr_count 23
# srx_mac 0c812662a980: src_addr_count 28
# srx_mac d007caced048: src_addr_count 82
# srx_mac 784f9b262575: src_addr_count 94
# srx_mac 0c8126202648: src_addr_count 34
# srx_mac f4cc55238d40: src_addr_count 13
# srx_mac 9ccc83b1f480: src_addr_count 260
# srx_mac fc3342635080: src_addr_count 42
# srx_mac c8e7f0cf3dc4: src_addr_count 9
# srx_mac 4c9614380200: src_addr_count 1
# srx_mac 4c9614978400: src_addr_count 160
# srx_mac 7c2586dbab49: src_addr_count 1241
# srx_mac fc3342640d80: src_addr_count 20
# srx_mac 4c9614927700: src_addr_count 1
# srx_mac 0c8126626800: src_addr_count 40
# srx_mac 045c6c171959: src_addr_count 24848
# srx_mac 30b64f22bc80: src_addr_count 9
# srx_mac c8e7f0cf22c4: src_addr_count 1
# srx_mac 4c9614ccb700: src_addr_count 1
# srx_mac ec13dbd51e01: src_addr_count 12
# srx_mac 4c96141d3c00: src_addr_count 1
# srx_mac 0c81266744e8: src_addr_count 26
# srx_mac 4c96147c8e00: src_addr_count 18
# srx_mac 84c1c1b04bc0: src_addr_count 4
# srx_mac fc334263c580: src_addr_count 68
# srx_mac 0c81261848c8: src_addr_count 1
# srx_mac 30b64f2ee0c0: src_addr_count 12
# srx_mac 4c9614386d00: src_addr_count 1
# srx_mac 4c96147e1400: src_addr_count 1
# srx_mac fc3342636080: src_addr_count 100
# srx_mac e8a245413803: src_addr_count 3
# srx_mac d0dd49716381: src_addr_count 291
# srx_mac 4c9614844f00: src_addr_count 1
# srx_mac d007ca6962c0: src_addr_count 26
# srx_mac 4071832aac00: src_addr_count 1
# srx_mac 20d80ba74102: src_addr_count 46
# srx_mac ec3873688cd0: src_addr_count 5
# srx_mac 30b64f2e6540: src_addr_count 11
# srx_mac b8c2537c2988: src_addr_count 273
# srx_mac 4c9614e00500: src_addr_count 5
# srx_mac 807ff81ea74a: src_addr_count 16
# srx_mac 4c9614532200: src_addr_count 1
# srx_mac d8b122ae6a00: src_addr_count 6
# srx_mac 20d80ba0c700: src_addr_count 3
# srx_mac 4c9614a89300: src_addr_count 1
# srx_mac 30b64f2e6b40: src_addr_count 398
# srx_mac 384f499fbe01: src_addr_count 50
# srx_mac 0c81262b2604: src_addr_count 2
# srx_mac 1039e94cd5c1: src_addr_count 745
# srx_mac d0dd49709901: src_addr_count 42
# srx_mac 4c9614dd2800: src_addr_count 1
# srx_mac d0dd49e00400: src_addr_count 7
# srx_mac ec13dbd54a80: src_addr_count 6
# srx_mac 30b64f21c980: src_addr_count 214
# srx_mac e8a245514eb2: src_addr_count 77
# srx_mac 94bf94bb8887: src_addr_count 86
# srx_mac fc3342641c00: src_addr_count 47
# srx_mac 94bf94b1986e: src_addr_count 33
# srx_mac d0dd49765481: src_addr_count 25
# srx_mac ec3873958c24: src_addr_count 6
# srx_mac e8a2455184b2: src_addr_count 26
# srx_mac 5800bbd8a881: src_addr_count 12
# srx_mac 4c9614df4700: src_addr_count 1
# srx_mac d0dd4971b400: src_addr_count 54
# srx_mac 4c9614eac100: src_addr_count 1
# srx_mac 0c812667c1e8: src_addr_count 7
# srx_mac 94bf94bbcb87: src_addr_count 46
# srx_mac f07cc7469b09: src_addr_count 293
# srx_mac d8b122d3aa81: src_addr_count 18
# srx_mac 0c812662a480: src_addr_count 183
# srx_mac e8a24551be32: src_addr_count 18
# srx_mac d8b122ac2e00: src_addr_count 384
# srx_mac ec3873638100: src_addr_count 4
# srx_mac 4c9614846200: src_addr_count 236
# srx_mac 045c6c91ab00: src_addr_count 16
# srx_mac f4bfa853d646: src_addr_count 3
# srx_mac f4bfa8521346: src_addr_count 12
# srx_mac 4c9614934500: src_addr_count 1
# srx_mac f4bfa8522846: src_addr_count 23
# srx_mac f07cc74a5a8c: src_addr_count 2
# srx_mac 94f7ada17180: src_addr_count 6
# srx_mac 94f7adf725a0: src_addr_count 12
# srx_mac e8a245513cb2: src_addr_count 16
# srx_mac fc334262bd80: src_addr_count 12
# srx_mac 5800bba87d00: src_addr_count 21
# srx_mac 4c9614dbe800: src_addr_count 1
# srx_mac 0c812667f568: src_addr_count 18
# srx_mac 30b64f219f00: src_addr_count 343
# srx_mac ec387368d450: src_addr_count 92

# %%
# For each srx box, how many unique src IPs
from pyspark.sql import functions as F, Window

# window_def = Window.partitionBy(F.col('site_id'), F.col('chassis_mac'), ).orderBy(F.col('rssi').desc())

srx_app_stats_df = df_completed_session.select('org_id',
                                               'site_id',
                                               'chassis_mac',
                                               'bytes_from_client',
                                               'bytes_from_server',
                                               'src_addr',
                                               'normalized_app',
                                               'session_total_time')\
.filter( ~F.col('normalized_app').isin(APP_NAMES_EXCLUDE_LIST))\
.groupby(['org_id', 'site_id', 'normalized_app'])\
.agg(F.avg('bytes_from_client').alias('avg_bytes_from_client'), 
     F.avg('bytes_from_server').alias('avg_bytes_from_server'),
     F.approxCountDistinct('src_addr').alias('src_addr_count'),
     F.count('site_id').alias('session_count'),
     F.avg('session_total_time').alias('avg_session_time'))

srx_app_stats_df.filter('org_id == "fe0ea1e2-2d95-43f2-9c6b-49d57eb01363" AND site_id == "494a84e3-5ca8-4ff6-ba66-07a4f59b8ec0"')\
.select('normalized_app', 
        'avg_bytes_from_client', 
        'avg_bytes_from_server', 
        'src_addr_count',
        'session_count',
        'avg_session_time').show()
# Out:
# +--------------------+---------------------+---------------------+--------------+-------------+------------------+
# |      normalized_app|avg_bytes_from_client|avg_bytes_from_server|src_addr_count|session_count|  avg_session_time|
# +--------------------+---------------------+---------------------+--------------+-------------+------------------+
# |              SMAATO|               2914.0|     8789.42857142857|             3|            7|54.857142857142854|
# |       GOOGLE-UPDATE|    3149.076923076923|   163566.92307692306|             4|           13|152.15384615384616|
# |    GOOGLE-APPENGINE|   1954.7777777777778|   3713.1111111111113|             3|            9|19.666666666666668|
# |                STUN|                120.0|                 60.0|             1|            2|              66.0|
# |     FACEBOOK-ACCESS|     21628.5105377907|   1018894.4672965116|            10|         2752| 88.97093023255815|
# |               IMGUR|   2500.4285714285716|    8190.714285714285|             3|            7|112.28571428571429|
# |               STARZ|    5075.263157894737|   22035.736842105263|             1|           19| 919.2105263157895|
# |              BRANCH|   2681.2688172043013|    8301.086021505376|             8|           93| 67.50537634408602|
# |                XBOX|    11167.95008912656|     281079.991087344|             3|         1122|244.70499108734404|
# |     GOOGLE-CALENDAR|     4831.37012987013|   14915.564935064935|             4|          154|22.474025974025974|
# |              JQUERY|   1883.5714285714287|   17021.285714285714|             2|            7|43.285714285714285|
# |              SONOBI|   2909.1951219512193|    5431.975609756098|             4|           41|3.8292682926829267|
# |             TEALIUM|   10645.333333333334|   35977.694444444445|             2|           36| 29.77777777777778|
# |      IOS-OTA-UPDATE|        1.222388725E7|        6.104942715E8|             2|            4|             165.0|
# |             TIDALTV|              2878.25|               9249.5|             1|            4|               9.0|
# |               BAIDU|               3552.0|              1258.35|             2|           20|            258.85|
# |              SIGNAL|   3097.1666666666665|    4597.041666666667|             2|           24| 8.958333333333334|
# |      APPLE-LOCATION|   4227.0103969754255|    20054.89981096408|             7|         1058| 36.14933837429111|
# |MICROSOFT-LIVE-SE...|    6238.963636363636|    13834.50909090909|             5|           55| 48.43636363636364|
# |        EVEREST-TECH|    3230.296296296296|    5769.148148148148|             4|           27| 65.51851851851852|
# +--------------------+---------------------+---------------------+--------------+-------------+------------------+
# only showing top 20 rows

# %%
stats = srx_app_stats_df.groupby(['org_id', 'site_id'])\
.agg(
      F.stddev_pop("avg_bytes_from_client").alias("sd_bytes_from_client"), 
      F.avg("avg_bytes_from_client").alias("av_bytes_from_client"),
    
      F.stddev_pop("avg_bytes_from_server").alias("sd_bytes_from_server"), 
      F.avg("avg_bytes_from_server").alias("av_bytes_from_server"),
    
      F.stddev_pop("src_addr_count").alias("sd_src_addr_count"), 
      F.avg("src_addr_count").alias("av_src_addr_count"),
    
      F.stddev_pop("session_count").alias("sd_session_count"), 
      F.avg("session_count").alias("av_session_count"),
    
      F.stddev_pop("avg_session_time").alias("sd_session_time"), 
      F.avg("avg_session_time").alias("av_session_time"),
).persist()
stats.filter('org_id == "fe0ea1e2-2d95-43f2-9c6b-49d57eb01363" AND site_id == "494a84e3-5ca8-4ff6-ba66-07a4f59b8ec0"')\
.select('sd_bytes_from_client', 'av_bytes_from_client',
        'sd_bytes_from_server', 'av_bytes_from_server',
        'sd_src_addr_count',    'av_src_addr_count',
        'sd_session_count',     'av_session_count',
        'sd_session_time',      'av_session_time').show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-----------------+------------------+-----------------+-----------------+-----------------+------------------+
# |sd_bytes_from_client|av_bytes_from_client|sd_bytes_from_server|av_bytes_from_server|sd_src_addr_count| av_src_addr_count| sd_session_count| av_session_count|  sd_session_time|   av_session_time|
# +--------------------+--------------------+--------------------+--------------------+-----------------+------------------+-----------------+-----------------+-----------------+------------------+
# |  1723460.2444405905|  197202.67735670044| 4.043639221119496E7|  2924593.7478275336|2.729066889941449|3.3656387665198237|907.8361653378562|263.8546255506608|1085.602558241837|209.12962997140698|
# +--------------------+--------------------+--------------------+--------------------+-----------------+------------------+-----------------+-----------------+-----------------+------------------+

# %%
marksColumns = [F.col('z_score_bfc'), 
                F.col('z_score_bfs'),
                F.col('z_score_sac'),
                F.col('z_score_sc'),
                F.col('z_score_st'),]


final_df = srx_app_stats_df.join(F.broadcast(stats), ['org_id', 'site_id'])\
.select('org_id', 'site_id', 'normalized_app',
        ((F.col('avg_bytes_from_client')-F.col('av_bytes_from_client'))/F.col('sd_bytes_from_client')).alias('z_score_bfc'),
        ((F.col('avg_bytes_from_server')-F.col('av_bytes_from_server'))/F.col('sd_bytes_from_server')).alias('z_score_bfs'),
        ((F.col('src_addr_count')-F.col('av_src_addr_count'))/F.col('sd_src_addr_count')).alias('z_score_sac'),
        ((F.col('session_count')-F.col('av_session_count'))/F.col('sd_session_count')).alias('z_score_sc'),
        ((F.col('avg_session_time')-F.col('av_session_time'))/F.col('sd_session_time')).alias('z_score_st'))\
.withColumn('avg_z_score', sum(x for x in marksColumns)/len(marksColumns))
            
final_df.filter('org_id == "fe0ea1e2-2d95-43f2-9c6b-49d57eb01363" AND site_id == "494a84e3-5ca8-4ff6-ba66-07a4f59b8ec0"')\
.select('normalized_app', 'avg_z_score').orderBy('avg_z_score', ascending=False).show()
# Out:
# +--------------------+------------------+
# |      normalized_app|       avg_z_score|
# +--------------------+------------------+
# |      IOS-OTA-UPDATE| 4.235249694769532|
# |              JABBER|2.7054233272625883|
# |          GOOGLE-GEN| 2.553222440710667|
# |                 GCS|2.4845102518729716|
# |            SNAPCHAT|2.0211078936998845|
# |      APPLE-FACETIME| 1.208462645539633|
# |              AMAZON|1.1429587256747988|
# |     FACEBOOK-ACCESS| 0.982411468039831|
# |          APPLE-PUSH|0.8130407936823831|
# |              ICLOUD|0.7913855484232588|
# |      NETFLIX-STREAM|0.7723771899915169|
# |       GOOGLE-STATIC|0.7560705454096723|
# |APPLE-IOS-UPDATE-SSL|0.7485653762810897|
# |           ICMP-ECHO|0.7445356297950931|
# |          GOOGLE-ADS|0.7205847619268234|
# |             YOUTUBE|0.7052678192870554|
# |          GOOGLE-API|0.5965251453690019|
# |           MICROSOFT|0.5789933719637672|
# |             OUTLOOK|0.5585192748777474|
# |           INSTAGRAM|0.5398477193113699|
# +--------------------+------------------+
# only showing top 20 rows

# %%
window_def = Window.partitionBy(F.col('org_id'), F.col('site_id'), ).orderBy(F.col('avg_z_score').desc())

site_top_app_df = final_df.withColumn('rank', F.rank().over(window_def)).filter('rank <= 10').persist()
site_top_app_df.select('site_id', 'normalized_app', 'avg_z_score', 'rank').show(80)
site_top_app_df.count()
# Out:
# +--------------------+--------------------+--------------------+----+
# |             site_id|      normalized_app|         avg_z_score|rank|
# +--------------------+--------------------+--------------------+----+
# |99a28ff4-3d06-476...|       junos-ike-nat|   4.378464715487214|   1|
# |99a28ff4-3d06-476...|           ICMP-ECHO|  2.4790751275470058|   2|
# |99a28ff4-3d06-476...|                 IKE|  1.7765438281834858|   3|
# |99a28ff4-3d06-476...|                 GCM|   1.374975357633944|   4|
# |99a28ff4-3d06-476...|          GOOGLE-GEN|  0.7020221742244768|   5|
# |99a28ff4-3d06-476...|       GOOGLE-STATIC|  0.6929262199829581|   6|
# |99a28ff4-3d06-476...|          GOOGLE-API|  0.6496831386722877|   7|
# |99a28ff4-3d06-476...|          APPLE-PUSH|  0.5031231178087767|   8|
# |99a28ff4-3d06-476...|             YOUTUBE|  0.4131054575365168|   9|
# |99a28ff4-3d06-476...|ANDROID-MARKETPLA...|  0.3763857932229509|  10|
# |33584048-90e4-40d...|          APPLE-PUSH|  0.8025754386006965|   1|
# |33584048-90e4-40d...|     FACEBOOK-ACCESS|  0.5688512945276628|   2|
# |33584048-90e4-40d...|      APPLE-LOCATION| 0.07276310317340987|   3|
# |33584048-90e4-40d...|              AMAZON|0.026408773172196164|   4|
# |33584048-90e4-40d...|              ICLOUD| -0.1481109435566999|   5|
# |33584048-90e4-40d...|            APPSTORE|-0.25960889891571454|   6|
# |33584048-90e4-40d...|APPLE-IOS-UPDATE-SSL| -0.3506867637290731|   7|
# |33584048-90e4-40d...|           ICMP-ECHO| -0.7121920032724777|   8|
# |e3b7b97c-e9a1-49a...|           ICMP-ECHO|  2.5645941726557906|   1|
# |e3b7b97c-e9a1-49a...|             AOL-ONE|    2.15811743388967|   2|
# |e3b7b97c-e9a1-49a...|              AMAZON|  2.0310972724092506|   3|
# |e3b7b97c-e9a1-49a...|     EASY-ANTI-CHEAT|  1.6544807827912642|   4|
# |e3b7b97c-e9a1-49a...|           NEW-RELIC|  1.4728872785947413|   5|
# |e3b7b97c-e9a1-49a...|              SYSLOG|    1.10157616839312|   6|
# |e3b7b97c-e9a1-49a...|                HULU|  1.0533239776646524|   7|
# |e3b7b97c-e9a1-49a...|             DISCORD|  0.7250859253015176|   8|
# |e3b7b97c-e9a1-49a...|      NETFLIX-STREAM|  0.7229814530354687|   9|
# |e3b7b97c-e9a1-49a...|          GOOGLE-GEN|  0.6104785799187599|  10|
# |8fcf021b-674e-4c7...|       junos-ike-nat|   2.893173668192991|   1|
# |8fcf021b-674e-4c7...|            MS-TEAMS|  1.0900327600249216|   2|
# |8fcf021b-674e-4c7...|                ospf|  1.0492121308201672|   3|
# |8fcf021b-674e-4c7...|           ICMP-ECHO|  0.8676675779193961|   4|
# |8fcf021b-674e-4c7...|APPLE-IOS-UPDATE-SSL|  0.6373475162452608|   5|
# |8fcf021b-674e-4c7...|OFFICE365-CREATE-...|  0.6000458928895686|   6|
# |8fcf021b-674e-4c7...|              AMAZON|  0.4487637824950467|   7|
# |8fcf021b-674e-4c7...|UNSPECIFIED-ENCRY...|  0.2383620647387744|   8|
# |8fcf021b-674e-4c7...|              ICLOUD|  0.2326970330285245|   9|
# |8fcf021b-674e-4c7...|             OUTLOOK| 0.19968015284494706|  10|
# |9455795c-1908-42c...|           ICMP-ECHO|                null|   1|
# |9455795c-1908-42c...|UNSPECIFIED-ENCRY...|                null|   1|
# |0c254faa-159f-451...|UNSPECIFIED-ENCRY...|  3.1876255504093494|   1|
# |0c254faa-159f-451...|           ICMP-ECHO|  2.0337260117582683|   2|
# |0c254faa-159f-451...|APPLE-IOS-UPDATE-SSL|0.058392708406889815|   3|
# |0c254faa-159f-451...|              ICLOUD| -0.0791379605515455|   4|
# |0c254faa-159f-451...|        APPLE-UPDATE|-0.09820285176742057|   5|
# |0c254faa-159f-451...|          APPLE-PUSH| -0.1480810925090302|   6|
# |0c254faa-159f-451...|           MICROSOFT|-0.16086479168119966|   7|
# |0c254faa-159f-451...|          GOOGLE-GEN|-0.16667462951828743|   8|
# |0c254faa-159f-451...|             ADDTHIS|  -0.168518390358445|   9|
# |0c254faa-159f-451...|      APPLE-LOCATION|-0.18424807070103327|  10|
# |623ed7fe-aae9-435...|        ESP-OVER-UDP|    8.26524398891433|   1|
# |623ed7fe-aae9-435...|           ICMP-ECHO|   2.633082835456748|   2|
# |623ed7fe-aae9-435...|          GOOGLE-GEN|  2.4289773581596252|   3|
# |623ed7fe-aae9-435...|           junos-ssh|  0.9702283396204605|   4|
# |623ed7fe-aae9-435...|              ICLOUD|   0.888968520016093|   5|
# |623ed7fe-aae9-435...|            SNAPCHAT|  0.5968833159168371|   6|
# |623ed7fe-aae9-435...|              AMAZON|  0.5519922511889038|   7|
# |623ed7fe-aae9-435...|APPLE-IOS-UPDATE-SSL| 0.42956720450615704|   8|
# |623ed7fe-aae9-435...|               GMAIL| 0.39058096659232033|   9|
# |623ed7fe-aae9-435...|       GOOGLE-STATIC|  0.3009083669616959|  10|
# |46d63b06-225d-4c3...|          GOOGLETALK|   5.209573442555414|   1|
# |46d63b06-225d-4c3...|           ICMP-ECHO|   3.556457944141971|   2|
# |46d63b06-225d-4c3...|           WEBSOCKET|  1.9898365340002744|   3|
# |46d63b06-225d-4c3...|              AMAZON|  1.5208702760082726|   4|
# |46d63b06-225d-4c3...|          APPLE-PUSH|  0.7749064036685194|   5|
# |46d63b06-225d-4c3...|                 GCM|  0.7722933517146503|   6|
# |46d63b06-225d-4c3...|          GOOGLE-GEN|  0.5328714085606345|   7|
# |46d63b06-225d-4c3...|             VERIZON|  0.4949791590524509|   8|
# |46d63b06-225d-4c3...|          GOOGLE-API|  0.3805751233174054|   9|
# |46d63b06-225d-4c3...|             YOUTUBE| 0.38040409439801637|  10|
# |e7c32791-6107-443...|         GOOGLE-DOCS|  1.8865938256779333|   1|
# |e7c32791-6107-443...|            MS-TEAMS|  1.4624831980909145|   2|
# |e7c32791-6107-443...|       GOOGLE-STATIC|   1.326741526198156|   3|
# |e7c32791-6107-443...|                 GCS|  1.2484192548610913|   4|
# |e7c32791-6107-443...|          GOOGLE-GEN|  0.7928891542866717|   5|
# |e7c32791-6107-443...|           MICROSOFT|  0.7881624102154411|   6|
# |e7c32791-6107-443...|           ICMP-ECHO|  0.7774050125880311|   7|
# |e7c32791-6107-443...|       GOOGLE-PHOTOS|  0.5678456351951955|   8|
# |e7c32791-6107-443...|APPLE-IOS-UPDATE-SSL|  0.4213338917929753|   9|
# |e7c32791-6107-443...|             OUTLOOK|  0.3887200623112971|  10|
# +--------------------+--------------------+--------------------+----+
# only showing top 80 rows
#
# 788
