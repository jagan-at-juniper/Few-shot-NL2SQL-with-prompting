# %%
from pyspark.sql.functions import udf, size, avg, count, col,sum, explode
import json
import datetime
env = "production"
env = "staging"

s3_bucket = "s3://mist-secorapp-{env}/mobile-client-marvis/mobile-client-marvis-{env}/".format(env=env)

date_day= datetime.datetime.today().strftime("%Y-%m-%d")
hr = '*'

date_day = "2020-05-1*"
# hr = '20'

s3_bucket += "dt={date}/{hr}/*.seq".format(date=date_day, hr=hr)

s3_path = s3_bucket 
print(s3_path)



# user_org_id = "38a18d4d-1623-4985-86d0-1bb06e5e2a48"  # UPS
# user_site_USNYELE = '9aa6ecdb-ddee-41b4-a8d9-872d7962b3c1'  #UPS USNYELE

# # user_org_id = '38a18d4d-1623-4985-86d0-1bb06e5e2a48'  # UPS
# user_site_USFLLON = 'c23667f3-47e9-44aa-9761-de49d34ed9f9' # USFLLON
# Out:
# s3://mist-secorapp-staging/mobile-client-marvis/mobile-client-marvis-staging/dt=2020-05-1*/*/*.seq

# %%
rdd = spark.sparkContext.sequenceFile(s3_path)

# %%
rdd.count()
# Out:
# 4008

# %%
test= rdd.first()
test
# Out:
# (591,
#  bytearray(b'{"Topic":"mobile-client-marvis-staging","HashKey":"3093b881-b5a8-4c3e-bd44-7464b0712a5d","Type":"Test send Basic Client Info plus Wifi or Cellular","Result":{"ClientInformation":{"Device":{"Manufacturer":"Samsung","Model":"SM-G970U1","Hardware":"qcom","RadioVersion":"G970U1UES3DTD5","OS":"Android","OSVersion":"10","MAC":"NotAvailable","BatteryPercentCharge":"94"},"SDK":{"MistID":"3093b881-b5a8-4c3e-bd44-7464b0712a5d","SDKName":"Marvis-Location-SDK 1.0","SDKVersion":"2.0.161","App":"Wakeup","AppVersion":"1.0(2)"},"ClientInfoTimestamp":"2020-05-11T19:46:25.0640Z"},"Stats":{"Passive":{"Tests":[{"ConnectionType":"WiFi","CellularData":{"Type":"WCDMA","AsuLevel":4,"RSSI":-105,"Level":1,"CellCID":151072024,"CellOperatorNumber":310260,"CellOperatorNameShort":"T-Mobile"},"WiFiConnectionData":{"BSSID":"5c:5b:35:03:d8:71","SignalStrength":99,"LinkSpeed":450,"Frequency":5660,"RSSI":-55,"SSID":"Marvis","NetworkId":11,"SupplicantState":"COMPLETED"},"WiFiScanData":[{"BSSID":"5c:5b:35:03:d8:71","SSID":"Marvis","Level":-57,"Frequency":5660,"WifiScanTimeStamp":162303629,"80211mcResponder":false,"ChannelBandwidth":"40","CenterFreq0":5670,"CenterFreq1":0}],"AirplaneModeOn":"false","Timestamp":"2020-05-11T19:46:25.0910Z"},{"ConnectionType":"WiFi","CellularData":{"Type":"WCDMA","AsuLevel":4,"RSSI":-105,"Level":1,"CellCID":151072024,"CellOperatorNumber":310260,"CellOperatorNameShort":"T-Mobile"},"WiFiConnectionData":{"BSSID":"5c:5b:35:03:d8:71","SignalStrength":99,"LinkSpeed":450,"Frequency":5660,"RSSI":-54,"SSID":"Marvis","NetworkId":11,"SupplicantState":"COMPLETED"},"WiFiScanData":[{"BSSID":"5c:5b:35:03:d8:71","SSID":"Marvis","Level":-57,"Frequency":5660,"WifiScanTimeStamp":162303629,"80211mcResponder":false,"ChannelBandwidth":"40","CenterFreq0":5670,"CenterFreq1":0}],"AirplaneModeOn":"false","Timestamp":"2020-05-11T19:46:26.0790Z"},{"ConnectionType":"WiFi","CellularData":{"Type":"WCDMA","AsuLevel":4,"RSSI":-105,"Level":1,"CellCID":151072024,"CellOperatorNumber":310260,"CellOperatorNameShort":"T-Mobile"},"WiFiConnectionData":{"BSSID":"5c:5b:35:03:d8:71","SignalStrength":99,"LinkSpeed":450,"Frequency":5660,"RSSI":-55,"SSID":"Marvis","NetworkId":11,"SupplicantState":"COMPLETED"},"WiFiScanData":[{"BSSID":"5c:5b:35:03:d8:71","SSID":"Marvis","Level":-57,"Frequency":5660,"WifiScanTimeStamp":162303629,"80211mcResponder":false,"ChannelBandwidth":"40","CenterFreq0":5670,"CenterFreq1":0}],"AirplaneModeOn":"false","Timestamp":"2020-05-11T19:46:27.0800Z"},{"ConnectionType":"WiFi","CellularData":{"Type":"WCDMA","AsuLevel":4,"RSSI":-105,"Level":1,"CellCID":151072024,"CellOperatorNumber":310260,"CellOperatorNameShort":"T-Mobile"},"WiFiConnectionData":{"BSSID":"5c:5b:35:03:d8:71","SignalStrength":99,"LinkSpeed":500,"Frequency":5660,"RSSI":-53,"SSID":"Marvis","NetworkId":11,"SupplicantState":"COMPLETED"},"WiFiScanData":[{"BSSID":"5c:5b:35:03:d8:71","SSID":"Marvis","Level":-57,"Frequency":5660,"WifiScanTimeStamp":162303629,"80211mcResponder":false,"ChannelBandwidth":"40","CenterFreq0":5670,"CenterFreq1":0}],"AirplaneModeOn":"false","Timestamp":"2020-05-11T19:46:28.0770Z"},{"ConnectionType":"WiFi","CellularData":{"Type":"WCDMA","AsuLevel":4,"RSSI":-105,"Level":1,"CellCID":151072024,"CellOperatorNumber":310260,"CellOperatorNameShort":"T-Mobile"},"WiFiConnectionData":{"BSSID":"5c:5b:35:03:d8:71","SignalStrength":99,"LinkSpeed":500,"Frequency":5660,"RSSI":-53,"SSID":"Marvis","NetworkId":11,"SupplicantState":"COMPLETED"},"WiFiScanData":[{"BSSID":"5c:5b:35:03:d8:61","SSID":"Marvis","Level":-40,"Frequency":2437,"WifiScanTimeStamp":205278191,"80211mcResponder":false,"ChannelBandwidth":"20","CenterFreq0":0,"CenterFreq1":0},{"BSSID":"5c:5b:35:00:4e:61","SSID":"\xf0\x9f\x98\x9b","Level":-40,"Frequency":2462,"WifiScanTimeStamp":205278228,"80211mcResponder":false,"ChannelBandwidth":"20","CenterFreq0":0,"CenterFreq1":0},{"BSSID":"5c:5b:35:03:f0:71","SSID":"@@@EU_Test@@@","Level":-43,"Frequency":5745,"WifiScanTimeStamp":205278185,"80211mcResponder":false,"ChannelBand ...

# %%
df= rdd.map(lambda x: json.loads(x[1])).toDF()
# Out:
# /opt/mistsys/ds_incubator/venv/spark-2.4.4-bin-without-hadoop/python/pyspark/sql/session.py:366: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead
#   warnings.warn("Using RDD of dict to inferSchema is deprecated. "

# %%
df.printSchema()
# Out:
# root
#  |-- HashKey: string (nullable = true)
#  |-- InfoFromTerminator: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#  |-- MarvisDataTimestamp: string (nullable = true)
#  |-- ReplyPath: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#  |-- Result: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: map (valueContainsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: map (valueContainsNull = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |-- Topic: string (nullable = true)
#  |-- Type: string (nullable = true)

# %%
df.show(10)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |             HashKey|  InfoFromTerminator| MarvisDataTimestamp|           ReplyPath|              Result|               Topic|                Type|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:46:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:46:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:46:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:47:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:47:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:47:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:47:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:47:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:47:...|[Topic -> client-...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |3093b881-b5a8-4c3...|[OrgID -> 9c3e516...|2020-05-11T19:48:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
data= rdd.map(lambda x: json.loads(x[1])).first()
import pprint

pprint.pprint(data)
# Out:
# {'HashKey': '3093b881-b5a8-4c3e-bd44-7464b0712a5d',
#  'InfoFromTerminator': {'ID': '9c3e516c-397d-11e6-ae35-0242ac110008.3093b881b5a84c3ebd447464b0712a5d',
#                         'OrgID': '9c3e516c-397d-11e6-ae35-0242ac110008',
#                         'RemoteAddr': '71.204.156.184:47498',
#                         'SiteID': None,
#                         'Terminator': 'client-terminator-001-staging',
#                         'Timestamp': '2020-05-11T19:46:34.494924604Z'},
#  'MarvisDataTimestamp': '2020-05-11T19:46:35.1770Z',
#  'ReplyPath': {'Opaque': 'AAAdgLZyjNb0W2YtN39ve1A7H+lAcmdmIOMuIvQLr06vFX1qIH7SpwJe80sev8mISogny+OGDLQFBwSq+M6IkeeLtsFhz2NGouNTg0ms7psMmxyTEjstFwhrhSBpVgdphzzBQ7RZe/k075wPRDr1xtdD+AGmVzM8NISn/UMkumfI8lVcF0V0eI0n597mJeyLMePZTJfV6GimoXUzUA6bJx4tCNDl9J0o+pz6hVEC',
#                'Topic': 'client-reply-client-terminator-001-staging'},
#  'Result': {'ClientInformation': {'ClientInfoTimestamp': '2020-05-11T19:46:25.0640Z',
#                                   'Device': {'BatteryPercentCharge': '94',
#                                              'Hardware': 'qcom',
#                                              'MAC': 'NotAvailable',
#                                              'Manufacturer': 'Samsung',
#                                              'Model': 'SM-G970U1',
#                                              'OS': 'Android',
#                                              'OSVersion': '10',
#                                              'RadioVersion': 'G970U1UES3DTD5'},
#                                   'SDK': {'App': 'Wakeup',
#                                           'AppVersion': '1.0(2)',
#                                           'MistID': '3093b881-b5a8-4c3e-bd44-7464b0712a5d',
#                                           'SDKName': 'Marvis-Location-SDK 1.0',
#                                           'SDKVersion': '2.0.161'}},
#             'Stats': {'Passive': {'PassiveTimestamp': '2020-05-11T19:46:35.1700Z',
#                                   'Tests': [{'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:25.0910Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 450,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -55,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 99,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:71',
#                                                                'CenterFreq0': 5670,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5660,
#                                                                'Level': -57,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 162303629}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:26.0790Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 450,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -54,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 99,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:71',
#                                                                'CenterFreq0': 5670,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5660,
#                                                                'Level': -57,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 162303629}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:27.0800Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 450,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -55,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 99,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:71',
#                                                                'CenterFreq0': 5670,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5660,
#                                                                'Level': -57,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 162303629}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:28.0770Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 500,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -53,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 99,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:71',
#                                                                'CenterFreq0': 5670,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5660,
#                                                                'Level': -57,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 162303629}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:29.0800Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 500,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -53,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 99,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2437,
#                                                                'Level': -40,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 205278191},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:00:4e:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -40,
#                                                                'SSID': '😛',
#                                                                'WifiScanTimeStamp': 205278228},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:f0:71',
#                                                                'CenterFreq0': 5755,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5745,
#                                                                'Level': -43,
#                                                                'SSID': '@@@EU_Test@@@',
#                                                                'WifiScanTimeStamp': 205278185},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c2',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': '@@@APHx_Wifi_Test@@@',
#                                                                'WifiScanTimeStamp': 205278197},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c6',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278203},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:e3',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278215},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:51',
#                                                                'CenterFreq0': 5190,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5180,
#                                                                'Level': -45,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278171},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:31',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2412,
#                                                                'Level': -46,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278156},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': 'b6:b6:86:1b:f2:8b',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -52,
#                                                                'SSID': 'DIRECT-8B-HP '
#                                                                        'ENVY '
#                                                                        'Photo '
#                                                                        '7800',
#                                                                'WifiScanTimeStamp': 205278222}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:30.0869Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 500,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -53,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 99,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2437,
#                                                                'Level': -40,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 205278191},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:00:4e:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -40,
#                                                                'SSID': '😛',
#                                                                'WifiScanTimeStamp': 205278228},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:f0:71',
#                                                                'CenterFreq0': 5755,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5745,
#                                                                'Level': -43,
#                                                                'SSID': '@@@EU_Test@@@',
#                                                                'WifiScanTimeStamp': 205278185},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c2',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': '@@@APHx_Wifi_Test@@@',
#                                                                'WifiScanTimeStamp': 205278197},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c6',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278203},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:e3',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278215},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:51',
#                                                                'CenterFreq0': 5190,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5180,
#                                                                'Level': -45,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278171},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:31',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2412,
#                                                                'Level': -46,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278156},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': 'b6:b6:86:1b:f2:8b',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -52,
#                                                                'SSID': 'DIRECT-8B-HP '
#                                                                        'ENVY '
#                                                                        'Photo '
#                                                                        '7800',
#                                                                'WifiScanTimeStamp': 205278222}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:31.0920Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 500,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -52,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 99,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2437,
#                                                                'Level': -40,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 205278191},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:00:4e:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -40,
#                                                                'SSID': '😛',
#                                                                'WifiScanTimeStamp': 205278228},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:f0:71',
#                                                                'CenterFreq0': 5755,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5745,
#                                                                'Level': -43,
#                                                                'SSID': '@@@EU_Test@@@',
#                                                                'WifiScanTimeStamp': 205278185},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c2',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': '@@@APHx_Wifi_Test@@@',
#                                                                'WifiScanTimeStamp': 205278197},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c6',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278203},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:e3',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278215},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:51',
#                                                                'CenterFreq0': 5190,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5180,
#                                                                'Level': -45,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278171},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:31',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2412,
#                                                                'Level': -46,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278156},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': 'b6:b6:86:1b:f2:8b',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -52,
#                                                                'SSID': 'DIRECT-8B-HP '
#                                                                        'ENVY '
#                                                                        'Photo '
#                                                                        '7800',
#                                                                'WifiScanTimeStamp': 205278222}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:32.0859Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 450,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -56,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 96,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2437,
#                                                                'Level': -40,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 205278191},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:00:4e:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -40,
#                                                                'SSID': '😛',
#                                                                'WifiScanTimeStamp': 205278228},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:f0:71',
#                                                                'CenterFreq0': 5755,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5745,
#                                                                'Level': -43,
#                                                                'SSID': '@@@EU_Test@@@',
#                                                                'WifiScanTimeStamp': 205278185},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c2',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': '@@@APHx_Wifi_Test@@@',
#                                                                'WifiScanTimeStamp': 205278197},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c6',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278203},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:e3',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278215},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:51',
#                                                                'CenterFreq0': 5190,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5180,
#                                                                'Level': -45,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278171},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:31',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2412,
#                                                                'Level': -46,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278156},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': 'b6:b6:86:1b:f2:8b',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -52,
#                                                                'SSID': 'DIRECT-8B-HP '
#                                                                        'ENVY '
#                                                                        'Photo '
#                                                                        '7800',
#                                                                'WifiScanTimeStamp': 205278222}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:33.0940Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 450,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -60,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 88,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2437,
#                                                                'Level': -40,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 205278191},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:00:4e:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -40,
#                                                                'SSID': '😛',
#                                                                'WifiScanTimeStamp': 205278228},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:f0:71',
#                                                                'CenterFreq0': 5755,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5745,
#                                                                'Level': -43,
#                                                                'SSID': '@@@EU_Test@@@',
#                                                                'WifiScanTimeStamp': 205278185},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c2',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': '@@@APHx_Wifi_Test@@@',
#                                                                'WifiScanTimeStamp': 205278197},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c6',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278203},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:e3',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278215},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:51',
#                                                                'CenterFreq0': 5190,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5180,
#                                                                'Level': -45,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278171},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:31',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2412,
#                                                                'Level': -46,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278156},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': 'b6:b6:86:1b:f2:8b',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -52,
#                                                                'SSID': 'DIRECT-8B-HP '
#                                                                        'ENVY '
#                                                                        'Photo '
#                                                                        '7800',
#                                                                'WifiScanTimeStamp': 205278222}]},
#                                             {'AirplaneModeOn': 'false',
#                                              'CellularData': {'AsuLevel': 4,
#                                                               'CellCID': 151072024,
#                                                               'CellOperatorNameShort': 'T-Mobile',
#                                                               'CellOperatorNumber': 310260,
#                                                               'Level': 1,
#                                                               'RSSI': -105,
#                                                               'Type': 'WCDMA'},
#                                              'ConnectionType': 'WiFi',
#                                              'Timestamp': '2020-05-11T19:46:34.0960Z',
#                                              'WiFiConnectionData': {'BSSID': '5c:5b:35:03:d8:71',
#                                                                     'Frequency': 5660,
#                                                                     'LinkSpeed': 450,
#                                                                     'NetworkId': 11,
#                                                                     'RSSI': -58,
#                                                                     'SSID': 'Marvis',
#                                                                     'SignalStrength': 92,
#                                                                     'SupplicantState': 'COMPLETED'},
#                                              'WiFiScanData': [{'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:d8:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2437,
#                                                                'Level': -40,
#                                                                'SSID': 'Marvis',
#                                                                'WifiScanTimeStamp': 205278191},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:00:4e:61',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -40,
#                                                                'SSID': '😛',
#                                                                'WifiScanTimeStamp': 205278228},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:03:f0:71',
#                                                                'CenterFreq0': 5755,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5745,
#                                                                'Level': -43,
#                                                                'SSID': '@@@EU_Test@@@',
#                                                                'WifiScanTimeStamp': 205278185},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c2',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': '@@@APHx_Wifi_Test@@@',
#                                                                'WifiScanTimeStamp': 205278197},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:c6',
#                                                                'CenterFreq0': 5795,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5785,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278203},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:54:9d:e3',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -43,
#                                                                'SSID': 'Test',
#                                                                'WifiScanTimeStamp': 205278215},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:51',
#                                                                'CenterFreq0': 5190,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '40',
#                                                                'Frequency': 5180,
#                                                                'Level': -45,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278171},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': '5c:5b:35:09:10:31',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2412,
#                                                                'Level': -46,
#                                                                'SSID': '@1235',
#                                                                'WifiScanTimeStamp': 205278156},
#                                                               {'80211mcResponder': False,
#                                                                'BSSID': 'b6:b6:86:1b:f2:8b',
#                                                                'CenterFreq0': 0,
#                                                                'CenterFreq1': 0,
#                                                                'ChannelBandwidth': '20',
#                                                                'Frequency': 2462,
#                                                                'Level': -52,
#                                                                'SSID': 'DIRECT-8B-HP '
#                                                                        'ENVY '
#                                                                        'Photo '
#                                                                        '7800',
#                                                                'WifiScanTimeStamp': 205278222}]}]}},
#             'StatsTimestamp': '2020-05-11T19:46:35.1710Z'},
#  'Topic': 'mobile-client-marvis-staging',
#  'Type': 'Test send Basic Client Info plus Wifi or Cellular'}

# %%
df= rdd.map(lambda x: json.loads(x[1])).toDF()

# %%
df_device= df.select(explode("Result.ClientInformation.Device"))

# %%
df_device.show()
# Out:
# +--------------------+--------------+
# |                 key|         value|
# +--------------------+--------------+
# |BatteryPercentCharge|            94|
# |                  OS|       Android|
# |               Model|     SM-G970U1|
# |        Manufacturer|       Samsung|
# |           OSVersion|            10|
# |            Hardware|          qcom|
# |        RadioVersion|G970U1UES3DTD5|
# |                 MAC|  NotAvailable|
# |BatteryPercentCharge|            94|
# |                  OS|       Android|
# |               Model|     SM-G970U1|
# |        Manufacturer|       Samsung|
# |           OSVersion|            10|
# |            Hardware|          qcom|
# |        RadioVersion|G970U1UES3DTD5|
# |                 MAC|  NotAvailable|
# |BatteryPercentCharge|            94|
# |                  OS|       Android|
# |               Model|     SM-G970U1|
# |        Manufacturer|       Samsung|
# +--------------------+--------------+
# only showing top 20 rows

# %%
df.select("Result.ClientInformation.Device").first()
# Out:
# Row(Device={'BatteryPercentCharge': '94', 'OS': 'Android', 'Model': 'SM-G970U1', 'Manufacturer': 'Samsung', 'OSVersion': '10', 'Hardware': 'qcom', 'RadioVersion': 'G970U1UES3DTD5', 'MAC': 'NotAvailable'})

# %%
df_device = df.select("HashKey",
                      "InfoFromTerminator.OrgID",
                      "MarvisDataTimestamp",
                      "Result.ClientInformation.Device.MAC",
                 "Result.ClientInformation.Device.Model",
                 "Result.ClientInformation.Device.OS",
                 "Result.ClientInformation.Device.OSVersion",
                 "Result.ClientInformation.Device.Hardware",
                 "Result.ClientInformation.Device.RadioVersion",
                 "Result.ClientInformation.Device.Manufacturer" 
                )

# %%
df_device.show()
# Out:
# +--------------------+--------------------+--------------------+------------+---------+-------+---------+--------+--------------+------------+
# |             HashKey|               OrgID| MarvisDataTimestamp|         MAC|    Model|     OS|OSVersion|Hardware|  RadioVersion|Manufacturer|
# +--------------------+--------------------+--------------------+------------+---------+-------+---------+--------+--------------+------------+
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:46:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:46:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:46:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:47:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:47:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:47:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:47:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:47:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:47:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:48:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:48:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:48:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:48:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:48:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:48:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:49:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:49:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:49:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:49:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# |3093b881-b5a8-4c3...|9c3e516c-397d-11e...|2020-05-11T19:50:...|NotAvailable|SM-G970U1|Android|       10|    qcom|G970U1UES3DTD5|     Samsung|
# +--------------------+--------------------+--------------------+------------+---------+-------+---------+--------+--------------+------------+
# only showing top 20 rows

# %%
df_device.groupBy("MAC", "OrgID").count().show(10, False)
# Out:
# +-----------------+------------------------------------+-----+
# |MAC              |OrgID                               |count|
# +-----------------+------------------------------------+-----+
# |2c-0e-3d-f8-ad-f9|eec9929e-4a8a-11e5-b454-1258369c38a9|574  |
# |d4-63-c6-eb-1f-a2|b578ad1b-7f7a-43f5-92a9-19b05f983d54|2079 |
# |NotAvailable     |eec9929e-4a8a-11e5-b454-1258369c38a9|13   |
# |NotAvailable     |b578ad1b-7f7a-43f5-92a9-19b05f983d54|870  |
# |NotAvailable     |9c3e516c-397d-11e6-ae35-0242ac110008|89   |
# |5c-41-5a-ba-e5-f8|eec9929e-4a8a-11e5-b454-1258369c38a9|383  |
# +-----------------+------------------------------------+-----+

# %%
df_device.groupBy("MAC",  "Model","OS","OSVersion","Hardware", "RadioVersion", "Manufacturer").count().show()
# Out:
# +-----------------+---------------+-------+---------+----------+--------------------+------------+-----+
# |              MAC|          Model|     OS|OSVersion|  Hardware|        RadioVersion|Manufacturer|count|
# +-----------------+---------------+-------+---------+----------+--------------------+------------+-----+
# |     NotAvailable|         KFMUWI|Android|    7.1.2|    mt8163|                    |      Amazon|   13|
# |     NotAvailable|       SM-G970F|Android|       10|exynos9820|G970FXXU3BSKL,G97...|     Samsung|  642|
# |2c-0e-3d-f8-ad-f9|       SM-G930U|Android|    8.0.0|      qcom|       G930UUESBCTA3|     Samsung|  574|
# |d4-63-c6-eb-1f-a2|Moto G (5) Plus|Android|    8.1.0|      qcom|M8953_41.50.07.85...|    Motorola| 2079|
# |     NotAvailable|      SM-G970U1|Android|       10|      qcom|      G970U1UES3DTD5|     Samsung|   89|
# |     NotAvailable|       SM-G970F|Android|        9|exynos9820|G970FXXS3ASJA,G97...|     Samsung|  228|
# |5c-41-5a-ba-e5-f8|         KFMUWI|Android|    7.1.2|    mt8163|                    |      Amazon|  383|
# +-----------------+---------------+-------+---------+----------+--------------------+------------+-----+

# %%
df_device.groupBy("MAC", "HashKey").count().orderBy("HashKey").show(50, False)
# Out:
# +-----------------+------------------------------------+-----+
# |MAC              |HashKey                             |count|
# +-----------------+------------------------------------+-----+
# |NotAvailable     |3093b881-b5a8-4c3e-bd44-7464b0712a5d|89   |
# |2c-0e-3d-f8-ad-f9|453e5b99-ea8f-4518-822b-7627b7d34c84|574  |
# |NotAvailable     |861d31dd-4e19-42a3-8ba4-e1325fe13e5d|13   |
# |5c-41-5a-ba-e5-f8|861d31dd-4e19-42a3-8ba4-e1325fe13e5d|383  |
# |d4-63-c6-eb-1f-a2|b385e302-a9ee-4c5e-b38b-d8f67c96fab1|2079 |
# |NotAvailable     |e041c687-8689-4474-83f4-ee941034ab04|870  |
# +-----------------+------------------------------------+-----+

# %%
df_c1 = df.filter(col("Result.ClientInformation.Device.MAC")=="2c-0e-3d-f8-ad-f9").show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |             HashKey|  InfoFromTerminator| MarvisDataTimestamp|           ReplyPath|              Result|               Topic|                Type|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:40:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:40:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:40:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:40:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:40:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:41:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:41:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:41:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:41:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:41:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:41:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:42:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:42:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:42:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:42:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:42:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:42:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:43:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:43:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# |453e5b99-ea8f-451...|[OrgID -> eec9929...|2020-05-12T19:43:...|[TCP -> 172.31.56...|[Stats -> [Passiv...|mobile-client-mar...|Test send Basic C...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
